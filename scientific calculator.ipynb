# %%
import math

def add(x, y):
    return x + y

def subtract(x, y):
    return x - y

def multiply(x, y):
    return x * y

def divide(x, y):
    if y == 0:
        return "Cannot divide by zero!"
    return x / y

def square_root(x):
    return math.sqrt(x)

def exponentiation(x, y):
    return x ** y

def sine(x):
    return math.sin(x)

def cosine(x):
    return math.cos(x)

def tangent(x):
    return math.tan(x)

def logarithm(x, base):
    return math.log(x, base)

def scientific_calculator():
    print("Scientific Calculator")
    print("Available operations:")
    print("1. Add")
    print("2. Subtract")
    print("3. Multiply")
    print("4. Divide")
    print("5. Square root")
    print("6. Exponentiation")
    print("7. Sine")
    print("8. Cosine")
    print("9. Tangent")
    print("10. Logarithm")

    while True:
        choice = input("Enter the operation number (or 'q' to quit): ")

        if choice == 'q':
            break

        if choice in ('1', '2', '3', '4', '6'):
            num1 = float(input("Enter first number: "))
            num2 = float(input("Enter second number: "))

            if choice == '1':
                print("Result:", add(num1, num2))
            elif choice == '2':
                print("Result:", subtract(num1, num2))
            elif choice == '3':
                print("Result:", multiply(num1, num2))
            elif choice == '4':
                print("Result:", divide(num1, num2))
            elif choice == '6':
                print("Result:", exponentiation(num1, num2))

        elif choice in ('5', '7', '8', '9', '10'):
            num = float(input("Enter the number: "))

            if choice == '5':
                print("Result:", square_root(num))
            elif choice == '7':
                print("Result:", sine(num))
            elif choice == '8':
                print("Result:", cosine(num))
            elif choice == '9':
                print("Result:", tangent(num))
            elif choice == '10':
                base = float(input("Enter the base of the logarithm: "))
                print("Result:", logarithm(num, base))

        else:
            print("Invalid input. Please try again.")

if __name__ == "__main__":
    scientific_calculator()
# Out:
# Scientific Calculator
# Available operations:
# 1. Add
# 2. Subtract
# 3. Multiply
# 4. Divide
# 5. Square root
# 6. Exponentiation
# 7. Sine
# 8. Cosine
# 9. Tangent
# 10. Logarithm
# Enter the operation number (or 'q' to quit): 5
# Enter the number: 12
# Result: 3.4641016151377544
# Enter the operation number (or 'q' to quit): 1
# Enter first number: 1
# Enter second number: 7
# Result: 8.0
# Enter the operation number (or 'q' to quit): 2
# Enter first number: 98
# Enter second number: 65
# Result: 33.0
# Enter the operation number (or 'q' to quit): q
